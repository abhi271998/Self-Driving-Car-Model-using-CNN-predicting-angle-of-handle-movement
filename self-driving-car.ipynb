# %%
import pandas
import numpy as np
from keras.preprocessing import image
from keras.layers import Conv2D,Flatten, Dense, Dropout
from keras.optimizers import Adam
from keras.models import Sequential
from keras import regularizers
from keras.optimizers import Adam
import scipy.misc
# import model
import cv2
from subprocess import call
import os

# print(os.listdir("./driving_dataset/"))

adam = Adam(0.0001)
L2NormConst = 0.001
model = Sequential()
model.add(Conv2D(24,[5,5],activation='relu',input_shape=[66,200,3],strides=[2,2],kernel_regularizer=regularizers.l2(0.001)))
model.add(Conv2D(36,[5,5],activation='relu',strides = [2,2],kernel_regularizer=regularizers.l2(0.001)))
model.add(Conv2D(48,[5,5],activation='relu',strides = [2,2],kernel_regularizer=regularizers.l2(0.001)))
model.add(Conv2D(64,[3,3],activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Conv2D(64,[3,3],activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.2))
model.add(Dense(24,activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.2))
model.add(Dense(1,activation='tanh',kernel_regularizer=regularizers.l2(0.001)))
model.summary()

model.compile(optimizer = adam,loss = 'mse', metrics = ['accuracy'])

model.load_weights('./zweights-0.0555.h5')

img_str = cv2.imread('steering_wheel_image.jpg',0)
rows,cols = img_str.shape

smoothed_angle = 0


i = 42500
while(cv2.waitKey(24) != ord('p') and i<45000):
	img1 = image.load_img("D:/driving_dataset/" + str(i) + ".jpg",color_mode='rgb')
	img1 = image.image.img_to_array(img1)/255.0
	img = image.load_img("D:/driving_dataset/" + str(i) + ".jpg",color_mode='rgb',target_size=[66,200])
	img = image.img_to_array(img)/255.0
	img_resh = np.reshape(img,[1,66,200,3])
	degrees = model.predict(img_resh) * 180.0 / scipy.pi
	print("Predicted steering angle: " + str(degrees) + " degrees")
	cv2.imshow("frame", cv2.cvtColor(img1, cv2.COLOR_RGB2BGR))
	smoothed_angle += 0.2 * pow(abs((degrees - smoothed_angle)), 2.0 / 3.0) * (degrees - smoothed_angle) / abs(degrees - smoothed_angle)
	M = cv2.getRotationMatrix2D((cols/2,rows/2),float(-smoothed_angle),1)
	dst = cv2.warpAffine(img_str,M,(cols,rows))
	cv2.imshow("steering wheel", dst)
	i += 1

cv2.destroyAllWindows()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_56 (Conv2D)           (None, 31, 98, 24)        1824
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 14, 47, 36)        21636
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 5, 22, 48)         43248
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 3, 20, 64)         27712
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 1, 18, 64)         36928
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1152)              0
# _________________________________________________________________
# dense_45 (Dense)             (None, 128)               147584
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_47 (Dense)             (None, 24)                1560
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 25
# =================================================================
# Total params: 288,773
# Trainable params: 288,773
# Non-trainable params: 0
# _________________________________________________________________
# Predicted steering angle: [[1.7921289]] degrees
# Predicted steering angle: [[1.7511785]] degrees
# Predicted steering angle: [[2.2309022]] degrees
# Predicted steering angle: [[2.0408294]] degrees
# Predicted steering angle: [[1.8141377]] degrees
# Predicted steering angle: [[2.1975951]] degrees
# Predicted steering angle: [[2.3951175]] degrees
# Predicted steering angle: [[2.675851]] degrees
# Predicted steering angle: [[2.5156076]] degrees
# Predicted steering angle: [[2.4502242]] degrees
# Predicted steering angle: [[2.645622]] degrees
# Predicted steering angle: [[2.5717268]] degrees
# Predicted steering angle: [[3.1896029]] degrees
# Predicted steering angle: [[3.479589]] degrees
# Predicted steering angle: [[4.152853]] degrees
# Predicted steering angle: [[4.0342274]] degrees
# Predicted steering angle: [[3.8312335]] degrees
# Predicted steering angle: [[2.6096437]] degrees
# Predicted steering angle: [[2.9828336]] degrees
# Predicted steering angle: [[2.9385505]] degrees
# Predicted steering angle: [[3.2935836]] degrees
# Predicted steering angle: [[3.3865526]] degrees
# Predicted steering angle: [[2.4408042]] degrees
# Predicted steering angle: [[2.1793973]] degrees
# Predicted steering angle: [[2.089477]] degrees
# Predicted steering angle: [[1.871186]] degrees
# Predicted steering angle: [[-0.9312997]] degrees
# Predicted steering angle: [[-0.08721159]] degrees
# Predicted steering angle: [[1.1806937]] degrees
# Predicted steering angle: [[1.8649803]] degrees
# Predicted steering angle: [[1.2746805]] degrees
# Predicted steering angle: [[0.7303019]] degrees
# Predicted steering angle: [[1.7192026]] degrees
# Predicted steering angle: [[1.4653275]] degrees
# Predicted steering angle: [[1.4958295]] degrees
# Predicted steering angle: [[1.761277]] degrees
# Predicted steering angle: [[1.0394117]] degrees
# Predicted steering angle: [[-0.04799553]] degrees
# Predicted steering angle: [[-1.85152]] degrees
# Predicted steering angle: [[-1.8795545]] degrees
# Predicted steering angle: [[-1.4096884]] degrees
# Predicted steering angle: [[-0.8350998]] degrees
# Predicted steering angle: [[0.28942057]] degrees
# Predicted steering angle: [[0.66520417]] degrees
# Predicted steering angle: [[0.99094135]] degrees
# Predicted steering angle: [[1.9915122]] degrees
# Predicted steering angle: [[1.6007421]] degrees
# Predicted steering angle: [[1.5210655]] degrees
# Predicted steering angle: [[2.1845875]] degrees
# Predicted steering angle: [[1.4116912]] degrees
# Predicted steering angle: [[2.0066152]] degrees
# Predicted steering angle: [[0.6037715]] degrees
# Predicted steering angle: [[2.1754825]] degrees
# Predicted steering angle: [[1.6070665]] degrees
# Predicted steering angle: [[1.902836]] degrees
# Predicted steering angle: [[1.7327408]] degrees
# Predicted steering angle: [[2.450412]] degrees
# Predicted steering angle: [[1.0068982]] degrees
# Predicted steering angle: [[0.23711428]] degrees
# Predicted steering angle: [[-0.21993248]] degrees
# Predicted steering angle: [[0.4558093]] degrees
# Predicted steering angle: [[1.4181087]] degrees
# Predicted steering angle: [[2.0264466]] degrees
# Predicted steering angle: [[1.8894384]] degrees
# Predicted steering angle: [[2.5170615]] degrees
# Predicted steering angle: [[-0.37383327]] degrees
# Predicted steering angle: [[-1.2604727]] degrees
# Predicted steering angle: [[-0.4802533]] degrees
# Predicted steering angle: [[-0.51922554]] degrees
# Predicted steering angle: [[-0.51634175]] degrees
# Predicted steering angle: [[1.1150467]] degrees
# Predicted steering angle: [[1.7098715]] degrees
# Predicted steering angle: [[-0.27592704]] degrees
# Predicted steering angle: [[0.38028654]] degrees
# Predicted steering angle: [[0.66862375]] degrees
# Predicted steering angle: [[0.7877145]] degrees
# Predicted steering angle: [[0.8428779]] degrees
# Predicted steering angle: [[1.2840513]] degrees
# Predicted steering angle: [[2.12291]] degrees
# Predicted steering angle: [[2.661433]] degrees
# Predicted steering angle: [[2.4998705]] degrees
# Predicted steering angle: [[2.273507]] degrees
# Predicted steering angle: [[2.3252747]] degrees
# Predicted steering angle: [[4.1109314]] degrees
# Predicted steering angle: [[7.5224805]] degrees
# Predicted steering angle: [[5.8220544]] degrees
# Predicted steering angle: [[2.3146527]] degrees
# Predicted steering angle: [[2.12981]] degrees
# Predicted steering angle: [[-1.6229513]] degrees
# Predicted steering angle: [[-0.6224919]] degrees
# Predicted steering angle: [[1.0346771]] degrees
# Predicted steering angle: [[4.8888564]] degrees
# Predicted steering angle: [[4.1143384]] degrees
# Predicted steering angle: [[6.1160345]] degrees
# Predicted steering angle: [[8.071392]] degrees
# Predicted steering angle: [[6.881761]] degrees
# Predicted steering angle: [[10.141546]] degrees
# Predicted steering angle: [[11.713114]] degrees
# Predicted steering angle: [[13.127087]] degrees
# Predicted steering angle: [[12.668282]] degrees
# Predicted steering angle: [[14.482284]] degrees
# Predicted steering angle: [[17.599136]] degrees
# Predicted steering angle: [[15.721326]] degrees
# Predicted steering angle: [[14.760727]] degrees
# Predicted steering angle: [[16.033186]] degrees
# Predicted steering angle: [[15.294251]] degrees
# Predicted steering angle: [[14.151465]] degrees
# Predicted steering angle: [[12.252388]] degrees
# Predicted steering angle: [[10.596768]] degrees
# Predicted steering angle: [[9.417666]] degrees
# Predicted steering angle: [[8.467123]] degrees
# Predicted steering angle: [[7.891213]] degrees
# Predicted steering angle: [[8.330822]] degrees
# Predicted steering angle: [[8.999056]] degrees
# Predicted steering angle: [[8.898853]] degrees
# Predicted steering angle: [[10.124102]] degrees
# Predicted steering angle: [[10.30976]] degrees
# Predicted steering angle: [[10.916876]] degrees
# Predicted steering angle: [[11.117344]] degrees
# Predicted steering angle: [[10.42539]] degrees
# Predicted steering angle: [[9.434611]] degrees
# Predicted steering angle: [[9.126423]] degrees
# Predicted steering angle: [[6.7503376]] degrees
# Predicted steering angle: [[7.117443]] degrees
# Predicted steering angle: [[7.106124]] degrees
# Predicted steering angle: [[6.6235085]] degrees
# Predicted steering angle: [[8.918459]] degrees
# Predicted steering angle: [[8.238836]] degrees
# Predicted steering angle: [[7.240087]] degrees
# Predicted steering angle: [[10.091963]] degrees
# Predicted steering angle: [[9.793239]] degrees
# Predicted steering angle: [[15.20132]] degrees
# Predicted steering angle: [[13.914081]] degrees
# Predicted steering angle: [[12.938007]] degrees
# Predicted steering angle: [[12.997817]] degrees
# Predicted steering angle: [[13.749793]] degrees
# Predicted steering angle: [[12.681733]] degrees
# Predicted steering angle: [[13.655705]] degrees
# Predicted steering angle: [[13.901844]] degrees
# Predicted steering angle: [[13.710525]] degrees
# Predicted steering angle: [[15.130885]] degrees
# Predicted steering angle: [[15.91695]] degrees
# Predicted steering angle: [[16.376593]] degrees
# Predicted steering angle: [[14.042855]] degrees
# Predicted steering angle: [[15.376137]] degrees
# Predicted steering angle: [[15.202583]] degrees
# Predicted steering angle: [[15.851208]] degrees
# Predicted steering angle: [[16.134857]] degrees
# Predicted steering angle: [[16.836103]] degrees
# Predicted steering angle: [[15.890361]] degrees
# Predicted steering angle: [[15.590946]] degrees
# Predicted steering angle: [[15.366397]] degrees
# Predicted steering angle: [[14.098117]] degrees
# Predicted steering angle: [[14.673528]] degrees
# Predicted steering angle: [[15.653481]] degrees
# Predicted steering angle: [[14.64234]] degrees
# Predicted steering angle: [[14.316402]] degrees
# Predicted steering angle: [[14.567083]] degrees
# Predicted steering angle: [[15.931755]] degrees
# Predicted steering angle: [[16.934053]] degrees
# Predicted steering angle: [[16.570135]] degrees
# Predicted steering angle: [[16.602175]] degrees
# Predicted steering angle: [[15.987159]] degrees
# Predicted steering angle: [[16.56928]] degrees
# Predicted steering angle: [[14.792689]] degrees
# Predicted steering angle: [[14.177496]] degrees
# Predicted steering angle: [[14.98691]] degrees
# Predicted steering angle: [[15.122926]] degrees
# Predicted steering angle: [[15.6473255]] degrees
# Predicted steering angle: [[14.511177]] degrees
# Predicted steering angle: [[16.156818]] degrees
# Predicted steering angle: [[15.950748]] degrees
# Predicted steering angle: [[16.875309]] degrees
# Predicted steering angle: [[15.942568]] degrees
# Predicted steering angle: [[15.11274]] degrees
# Predicted steering angle: [[15.255545]] degrees
# Predicted steering angle: [[16.78739]] degrees
# Predicted steering angle: [[16.565607]] degrees
# Predicted steering angle: [[17.501667]] degrees
# Predicted steering angle: [[17.573008]] degrees
# Predicted steering angle: [[18.170639]] degrees
# Predicted steering angle: [[17.92147]] degrees
# Predicted steering angle: [[18.171352]] degrees
# Predicted steering angle: [[18.864183]] degrees
# Predicted steering angle: [[17.63493]] degrees
# Predicted steering angle: [[18.817371]] degrees
# Predicted steering angle: [[20.340181]] degrees
# Predicted steering angle: [[20.596746]] degrees
# Predicted steering angle: [[20.32342]] degrees
# Predicted steering angle: [[19.666538]] degrees
# Predicted steering angle: [[19.228865]] degrees
# Predicted steering angle: [[18.355349]] degrees
# Predicted steering angle: [[17.393093]] degrees
# Predicted steering angle: [[18.809984]] degrees
# Predicted steering angle: [[18.361052]] degrees
# Predicted steering angle: [[17.59233]] degrees
# Predicted steering angle: [[18.07563]] degrees
# Predicted steering angle: [[18.18241]] degrees
# Predicted steering angle: [[18.784567]] degrees
# Predicted steering angle: [[18.229265]] degrees
# Predicted steering angle: [[18.716667]] degrees
# Predicted steering angle: [[19.192598]] degrees
# Predicted steering angle: [[20.33875]] degrees
# Predicted steering angle: [[20.420385]] degrees
# Predicted steering angle: [[20.28272]] degrees
# Predicted steering angle: [[21.25995]] degrees
# Predicted steering angle: [[21.209583]] degrees
# Predicted steering angle: [[20.924665]] degrees
# Predicted steering angle: [[20.703114]] degrees
# Predicted steering angle: [[19.629818]] degrees
# Predicted steering angle: [[19.869427]] degrees
# Predicted steering angle: [[21.121994]] degrees
# Predicted steering angle: [[20.490917]] degrees
# Predicted steering angle: [[21.501862]] degrees
